# %%
print("hello")
# Out:
# hello

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
movies = pd.read_csv('tmdb_5000_movies.csv')
credits = pd.read_csv('tmdb_5000_credits.csv')

# %%
movies.head(2)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
#
#                                        homepage     id  \
# 0                   http://www.avatarmovie.com/  19995
# 1  http://disney.go.com/disneypictures/pirates/    285
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
#
# ...

# %%
movies.shape
# Out:
# (4803, 20)

# %%
credits.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
movies = movies.merge(credits,on='title')

# %%
movies.head()
# budget
# homepage
# id
# original_language
# original_title
# popularity
# production_comapny
# production_countries
# release-date(not sure)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
movies = movies[['movie_id','title','overview','genres','keywords','cast','crew']]

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# ...

# %%
import ast

# %%
def convert(text):
    L = []
    for i in ast.literal_eval(text):
        L.append(i['name']) 
    return L

# %%
movies.dropna(inplace=True)

# %%
movies['genres'] = movies['genres'].apply(convert)
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %%
movies['keywords'] = movies['keywords'].apply(convert)
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %%
import ast
ast.literal_eval('[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]')
# Out:
# [{'id': 28, 'name': 'Action'},
#  {'id': 12, 'name': 'Adventure'},
#  {'id': 14, 'name': 'Fantasy'},
#  {'id': 878, 'name': 'Science Fiction'}]

# %%
def convert3(text):
    L = []
    counter = 0
    for i in ast.literal_eval(text):
        if counter < 3:
            L.append(i['name'])
        counter+=1
    return L

# %%
movies['cast'] = movies['cast'].apply(convert)
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %%
movies['cast'] = movies['cast'].apply(lambda x:x[0:3])

# %%
def fetch_director(text):
    L = []
    for i in ast.literal_eval(text):
        if i['job'] == 'Director':
            L.append(i['name'])
    return L

# %%
movies['crew'] = movies['crew'].apply(fetch_director)

# %%
#movies['overview'] = movies['overview'].apply(lambda x:x.split())
movies.sample(5)
# Out:
#       movie_id                            title  \
# 1906      1831              The Next Best Thing
# 36       91314  Transformers: Age of Extinction
# 254      41513                       The Smurfs
# 3796    125123                     Among Giants
# 110        676                     Pearl Harbor
#
#                                                overview  \
# 1906  A comedy-drama about best friends - one a stra...
# 36    As humanity picks up the pieces, following the...
# 254   When the evil wizard Gargamel chases the tiny ...
# 3796  A manager hires Ray, off the books, to paint a...
# 110   The lifelong friendship between Rafe McCawley ...
#
#                                                genres  \
# 1906                                         [Comedy]
# 36               [Science Fiction, Action, Adventure]
# 254   [Animation, Family, Adventure, Comedy, Fantasy]
# 3796                                [Comedy, Romance]
# 110                           [History, Romance, War]
#
# ...

# %%
def collapse(L):
    L1 = []
    for i in L:
        L1.append(i.replace(" ",""))
    return L1

# %%
movies['cast'] = movies['cast'].apply(collapse)
movies['crew'] = movies['crew'].apply(collapse)
movies['genres'] = movies['genres'].apply(collapse)
movies['keywords'] = movies['keywords'].apply(collapse)

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                          genres  \
# 0  [Action, Adventure, Fantasy, ScienceFiction]
# 1                  [Adventure, Fantasy, Action]
# 2                    [Action, Adventure, Crime]
# 3              [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, ScienceFiction]
#
# ...

# %%
movies['overview'] = movies['overview'].apply(lambda x:x.split())

# %%
movies['tags'] = movies['overview'] + movies['genres'] + movies['keywords'] + movies['cast'] + movies['crew']

# %%
new = movies.drop(columns=['overview','genres','keywords','cast','crew'])
#new.head()

# %%
new['tags'] = new['tags'].apply(lambda x: " ".join(x))
new.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 tags
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=5000,stop_words='english')

# %%
vector = cv.fit_transform(new['tags']).toarray()

# %%
vector.shape
# Out:
# (4806, 5000)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity = cosine_similarity(vector)

# %%
similarity
# Out:
# array([[1.        , 0.08964215, 0.06071767, ..., 0.02519763, 0.0277885 ,
#         0.        ],
#        [0.08964215, 1.        , 0.06350006, ..., 0.02635231, 0.        ,
#         0.        ],
#        [0.06071767, 0.06350006, 1.        , ..., 0.02677398, 0.        ,
#         0.        ],
#        ...,
#        [0.02519763, 0.02635231, 0.02677398, ..., 1.        , 0.07352146,
#         0.04774099],
#        [0.0277885 , 0.        , 0.        , ..., 0.07352146, 1.        ,
#         0.05264981],
#        [0.        , 0.        , 0.        , ..., 0.04774099, 0.05264981,
#         1.        ]], shape=(4806, 4806))

# %%
new[new['title'] == 'The Lego Movie'].index[0]
# Out:
# np.int64(744)

# %%
def recommend(movie):
    index = new[new['title'] == movie].index[0]
    distances = sorted(list(enumerate(similarity[index])),reverse=True,key = lambda x: x[1])
    for i in distances[1:6]:
        print(new.iloc[i[0]].title)

# %%
recommend('Batman')
# Out:
# Batman
# Batman & Robin
# The Dark Knight Rises
# Batman Begins
# Batman Returns

# %%
def recommend_with_scores(movie, top_n=20):

    if movie not in new['title'].values:
        print(f"{movie} not found!")
        return []

    index = new[new['title'] == movie].index[0]

    distances = sorted(
        list(enumerate(similarity[index])),
        reverse=True,
        key=lambda x: x[1]
    )[1:top_n+1]

    recommendations = []

    for idx, score in distances:

        recommendations.append(
            (
                new.iloc[idx]['title'],
                score
            )
        )

    return recommendations

# %%
recommend_with_scores("Avatar")
# Out:
# [('Titan A.E.', np.float64(0.26089696604360174)),
#  ('Small Soldiers', np.float64(0.2581988897471611)),
#  ("Ender's Game", np.float64(0.25110592822973776)),
#  ('Aliens vs Predator: Requiem', np.float64(0.24944382578492943)),
#  ('Independence Day', np.float64(0.24846467329894412)),
#  ('Krull', np.float64(0.24397501823713333)),
#  ('Lifeforce', np.float64(0.243599382882345)),
#  ('Battle: Los Angeles', np.float64(0.24147264420814757)),
#  ('Falcon Rising', np.float64(0.23904572186687872)),
#  ('Edge of Tomorrow', np.float64(0.22677868380553634)),
#  ('Apollo 18', np.float64(0.2238868314198225)),
#  ('The Fifth Element', np.float64(0.22230800575069137)),
#  ('The Lovers', np.float64(0.22190115272469205)),
#  ('Independence Daysaster', np.float64(0.22131333406899523)),
#  ('Predator', np.float64(0.2173253797873328)),
#  ('Predators', np.float64(0.21653278478430665)),
#  ('Star Trek Into Darkness', np.float64(0.2164218276749025)),
# ...

# %%
from collections import defaultdict

def group_recommend(movie_list, top_n=10):

    movie_scores = defaultdict(float)
    movie_votes = defaultdict(int)

    for movie in movie_list:

        recommendations = recommend_with_scores(movie)

        for rec_movie, score in recommendations:

            if rec_movie not in movie_list:

                movie_scores[rec_movie] += score
                movie_votes[rec_movie] += 1

    results = []

    for movie in movie_scores:

        avg_score = movie_scores[movie] / movie_votes[movie]

        results.append({
            "Movie": movie,
            "Votes": movie_votes[movie],
            "Average Cosine": avg_score,
            "Total Cosine": movie_scores[movie]
        })

    results = sorted(
        results,
        key=lambda x: (
            x["Votes"],
            x["Average Cosine"]
        ),
        reverse=True
    )

    return results[:top_n]

# %%
results = group_recommend(
    [
        "Avatar",
        "Iron Man",
        "Gandhi"
    ]
)

for i, movie in enumerate(results,1):

    print(
        f"{i}. {movie['Movie']}"
        f"\n   Votes : {movie['Votes']}"
        f"\n   Avg Cosine : {movie['Average Cosine']:.3f}"
        f"\n   Total Cosine : {movie['Total Cosine']:.3f}\n"
    )
# Out:
# 1. Iron Man 2
#    Votes : 1
#    Avg Cosine : 0.484
#    Total Cosine : 0.484
#
# 2. Iron Man 3
#    Votes : 1
#    Avg Cosine : 0.445
#    Total Cosine : 0.445
#
# 3. Avengers: Age of Ultron
#    Votes : 1
#    Avg Cosine : 0.380
#    Total Cosine : 0.380
#
# 4. Captain America: Civil War
#    Votes : 1
#    Avg Cosine : 0.298
#    Total Cosine : 0.298
#
# 5. The Avengers
#    Votes : 1
#    Avg Cosine : 0.286
#    Total Cosine : 0.286
#
# 6. Ant-Man
#    Votes : 1
#    Avg Cosine : 0.279
#    Total Cosine : 0.279
#
# 7. Gandhi, My Father
#    Votes : 1
#    Avg Cosine : 0.261
#    Total Cosine : 0.261
#
# 8. Titan A.E.
#    Votes : 1
#    Avg Cosine : 0.261
#    Total Cosine : 0.261
#
# 9. X-Men
#    Votes : 1
#    Avg Cosine : 0.259
#    Total Cosine : 0.259
#
# 10. Small Soldiers
#    Votes : 1
#    Avg Cosine : 0.258
#    Total Cosine : 0.258

# %%
group = ["Avatar", "Iron Man", "Gandhi"]

results = group_recommend(group)

for movie in results:
    print(movie)
# Out:
# {'Movie': 'Iron Man 2', 'Votes': 1, 'Average Cosine': np.float64(0.48418202613504197), 'Total Cosine': np.float64(0.48418202613504197)}
# {'Movie': 'Iron Man 3', 'Votes': 1, 'Average Cosine': np.float64(0.4447495899966607), 'Total Cosine': np.float64(0.4447495899966607)}
# {'Movie': 'Avengers: Age of Ultron', 'Votes': 1, 'Average Cosine': np.float64(0.38005847503304596), 'Total Cosine': np.float64(0.38005847503304596)}
# {'Movie': 'Captain America: Civil War', 'Votes': 1, 'Average Cosine': np.float64(0.29834709485930816), 'Total Cosine': np.float64(0.29834709485930816)}
# {'Movie': 'The Avengers', 'Votes': 1, 'Average Cosine': np.float64(0.2863281433391), 'Total Cosine': np.float64(0.2863281433391)}
# {'Movie': 'Ant-Man', 'Votes': 1, 'Average Cosine': np.float64(0.279078152825719), 'Total Cosine': np.float64(0.279078152825719)}
# {'Movie': 'Gandhi, My Father', 'Votes': 1, 'Average Cosine': np.float64(0.2611164839335468), 'Total Cosine': np.float64(0.2611164839335468)}
# ...

# %%
import streamlit as st

movie_names = sorted(new['title'].unique())

friend1 = st.selectbox("Friend 1", movie_names)
friend2 = st.selectbox("Friend 2", movie_names)
friend3 = st.selectbox("Friend 3", movie_names)
friend4 = st.selectbox("Friend 4", [""] + movie_names)

if st.button("Recommend"):

    group = [friend1, friend2, friend3]

    if friend4 != "":
        group.append(friend4)

    results = group_recommend(group)

    st.subheader("Recommended Movies")

    for movie in results:

        st.write(f"🎬 {movie['Movie']}")
        st.write(f"Votes: {movie['Votes']}")
        st.write(f"Average Cosine: {movie['Average Cosine']:.3f}")
        st.write("---")
# Out:
# 2026-07-24 23:40:56.419 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-24 23:40:56.420 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-24 23:40:56.421 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-24 23:40:56.421 WARNING streamlit.runtime.state.session_state_proxy: Session state does not function when running a script without `streamlit run`
# 2026-07-24 23:40:56.421 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-24 23:40:56.482
# ...
#   command:
#
# ...

# %%
import pickle

# %%
import pickle

pickle.dump(new, open("movies.pkl", "wb"))
pickle.dump(similarity, open("similarity.pkl", "wb"))

# %%
import os

print(os.listdir())
# Out:
# ['similarity.pkl', 'movies.pkl', 'tmdb_5000_credits.csv', 'notebook86c26b4f17.ipynb', 'tmdb_5000_movies.csv', '.venv', 'movie_list.pkl', 'app.py', '.Rapp.history', '.idea']

# %%
new.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 tags
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...

# %%
new.columns
# Out:
# Index(['movie_id', 'title', 'tags'], dtype='str')

# %%
import os

print("movies.pkl:", os.path.getsize("movies.pkl"))
print("similarity.pkl:", os.path.getsize("similarity.pkl"))
print("movie_list.pkl:", os.path.getsize("movie_list.pkl"))
# Out:
# movies.pkl: 2431703
# similarity.pkl: 184781252
# movie_list.pkl: 2431703
